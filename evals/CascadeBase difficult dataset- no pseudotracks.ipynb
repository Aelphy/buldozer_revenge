# %%
#ipynb config
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
print 1
# Out:
# 1

# %%
from sklearn.cross_validation import train_test_split
from models.cascade_base import CascadeBase
from utils.visualizer import Visualizer
from IPython.display import SVG, display

import numpy as np
import matplotlib.pyplot as plt

import time
# import pydot
import lasagne

plt.style.use('ggplot')

# %matplotlib inline

# %%
def get_hex_color(layer_type):
    """
    Determines the hex color for a layer.
    :parameters:
        - layer_type : string
            Class name of the layer
    :returns:
        - color : string containing a hex color for filling block.
    """
    COLORS = ['#4A88B3', '#98C1DE', '#6CA2C8', '#3173A2', '#17649B',
              '#FFBB60', '#FFDAA9', '#FFC981', '#FCAC41', '#F29416',
              '#C54AAA', '#E698D4', '#D56CBE', '#B72F99', '#B0108D',
              '#75DF54', '#B3F1A0', '#91E875', '#5DD637', '#3FCD12']

    hashed = int(hash(layer_type)) % 5

    if "conv" in layer_type.lower():
        return COLORS[:5][hashed]
    if layer_type in lasagne.layers.pool.__all__:
        return COLORS[5:10][hashed]
    if layer_type in lasagne.layers.recurrent.__all__:
        return COLORS[10:15][hashed]
    else:
        return COLORS[15:20][hashed]

def make_pydot_graph(layers, output_shape=True, verbose=False):
    """
    :parameters:
        - layers : list
            List of the layers, as obtained from lasagne.layers.get_all_layers
        - output_shape: (default `True`)
            If `True`, the output shape of each layer will be displayed.
        - verbose: (default `False`)
            If `True`, layer attributes like filter shape, stride, etc.
            will be displayed.
    :returns:
        - pydot_graph : PyDot object containing the graph
    """

    pydot_graph = pydot.Dot('Network', graph_type='digraph')
    pydot_nodes = {}
    pydot_edges = []
    for i, layer in enumerate(layers):
        layer_type = '{0}'.format(layer.__class__.__name__)
        layer_name = layer.name if layer.name is not None else ''
        key = repr(layer)
        label = layer_name + ' ' + layer_type
        color = get_hex_color(layer_type)
        if verbose:
            for attr in ['num_filters', 'num_units', 'ds',
                         'filter_shape', 'stride', 'strides', 'p']:
                if hasattr(layer, attr):
                    label += '\n{0}: {1}'.format(attr, getattr(layer, attr))
            if hasattr(layer, 'nonlinearity'):
                try:
                    nonlinearity = layer.nonlinearity.__name__
                except AttributeError:
                    nonlinearity = layer.nonlinearity.__class__.__name__
                label += '\nnonlinearity: {0}'.format(nonlinearity)

        if output_shape:
            label += '\nOutput shape: {0}'.format(layer.output_shape)

        pydot_nodes[key] = pydot.Node(
            key, label=label, shape='record', fillcolor=color, style='filled')

        if hasattr(layer, 'input_layers'):
            for input_layer in layer.input_layers:
                pydot_edges.append([repr(input_layer), key])

        if hasattr(layer, 'input_layer'):
            pydot_edges.append([repr(layer.input_layer), key])

    for node in pydot_nodes.values():
        pydot_graph.add_node(node)

    for edges in pydot_edges:
        pydot_graph.add_edge(
            pydot.Edge(pydot_nodes[edges[0]], pydot_nodes[edges[1]]))
    return pydot_graph

def iterate_minibatches(inputs, targets, batch_size):
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    
    for start_idx in range(0, len(inputs) - batch_size + 1, batch_size):
        excerpt = indices[start_idx:start_idx + batch_size]

        yield inputs[excerpt], targets[excerpt]


def learn(nn,
          dataset,
          watches=['obj',
                   'recall',
                   'precision',
                   'accuracy',
                   'loss',
                   'sub_loss'],
          num_epochs=100,
          batch_size=50):
    '''
        num_epochs - amount of passes through the data
        batch_size - number of samples processed at each function call
        dataset - [X_train, X_val, y_train, y_val]
    '''
    # %matplotlib notebook
    
    X_train, X_val, y_train, y_val = dataset
    metrics_template = dict()
    
    metrics_sample = nn.evaluate(X_val[:2], y_val[:2])
    
    for metric_name, _ in metrics_sample.items():
        if metric_name == 'complexity_parts':
            metrics_template[metric_name] = [0] * len(metrics_sample[metric_name])
        else:
            metrics_template[metric_name] = 0
        
    visualizer = Visualizer(num_epochs,
                            metrics_template,
                            watches=watches)
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        start_time = time.time()
        
        train_measurements = dict(metrics_template)
        train_batches = 0

        for batch in iterate_minibatches(X_train, y_train, batch_size):
            inputs, targets = batch
            
            for metric_name, metric in nn.train(inputs, targets).items():
                if metric_name == 'complexity_parts':
                    for j in range(len(metrics_template[metric_name])):
                        train_measurements[metric_name][j] += metric[j]
                else: 
                    train_measurements[metric_name] += metric

            train_batches += 1
            
        for metric_name, metric in train_measurements.items():
            if metric_name == 'complexity_parts':
                for j in range(len(metrics_template[metric_name])):
                    train_measurements[metric_name][j] = metric[j] / train_batches
            else: 
                train_measurements[metric_name] = metric / train_batches

        # And a full pass over the validation data:
        val_measurements = dict(metrics_template)
        val_batches = 0

        for batch in iterate_minibatches(X_val, y_val, batch_size):
            inputs, targets = batch
            
            for metric_name, metric in nn.evaluate(inputs, targets).items():
                if metric_name == 'complexity_parts':
                    for j in range(len(metrics_template[metric_name])):
                        val_measurements[metric_name][j] += metric[j]
                else: 
                    val_measurements[metric_name] += metric

            val_batches += 1
            
        for metric_name, metric in val_measurements.items():
            if metric_name == 'complexity_parts':
                for j in range(len(metrics_template[metric_name])):
                    val_measurements[metric_name][j] = metric[j] / val_batches
            else: 
                val_measurements[metric_name] = metric / val_batches

        print('Epoch {} of {} took {:.3f}s'.format(epoch + 1, num_epochs, time.time() - start_time))
        visualizer.watch(train_measurements, val_measurements)
    visualizer.finish()
    
def draw(network):
    with open('../images/net.svg', 'w') as f:
        g = make_pydot_graph(lasagne.layers.get_all_layers(network))
        f.write(g.create_svg(f='svg'))

    display(SVG(filename='../images/net.svg'))

# %%
dataset0 = np.load('../data/clean_artificial/imgs_0038.npy').reshape(-1, 1, 512, 512).astype(np.float32)
targets0 = np.load('../data/clean_artificial/masks_0038.npy').reshape(-1, 1, 512, 512).astype(np.float32)
dataset1 = np.load('../data/clean_artificial/imgs_0022.npy').reshape(-1, 1, 512, 512).astype(np.float32)
targets1 = np.load('../data/clean_artificial/masks_0022.npy').reshape(-1, 1, 512, 512).astype(np.float32)

dataset = np.vstack((dataset0, dataset1))
targets = np.vstack((targets0, targets1))

track_targets = targets.copy()
track_targets[track_targets <=0] = 0

# %%
X_y = train_test_split(dataset, track_targets)

# %%
dataset.shape
# Out:
# (2000, 1, 512, 512)

# %% [markdown]
# ## Train the network

# %%
network = CascadeBase(img_shape=(512, 512),
                      learning_rate=1e-3,
                      c=1e-1,
                      c_complexity=1e-3,
                      c_sub_objs=[1e-4, 1e-3, 1e-2, 1e-1],
                      c_sub_obj_cs=[1e-1, 1e-1, 1e-1, 1e-1],
                      mul=True,
                      pool_sizes=[2, 2, 2, 2],
                      num_filters=[1, 1, 3, 6],
                      filter_sizes=[1, 3, 3, 3],
                      l2_c=1e-4)

# %%
network.load('../weights/', '3cascades_difficult_clear')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2d8d8a93500c> in <module>()
# ----> 1 network.load('../weights/', '3cascades_difficult_clear')
#
# /home/mborisya/aelphy/muon_trigger/models/cascade_base.pyc in load(self, path, name)
#     259         with np.load(os.path.join(path, name + '.npz')) as f:
#     260             param_values = [f['arr_%d' % i] for i in range(len(f.files))]
# --> 261             lasagne.layers.set_all_param_values(self.masked_output_layer, param_values)
#
# /home/mborisya/opt/anaconda2/lib/python2.7/site-packages/lasagne/layers/helper.pyc in set_all_param_values(layer, values, **tags)
#     516             raise ValueError("mismatch: parameter has shape %r but value to "
#     517                              "set has shape %r" %
# --> 518                              (p.get_value().shape, v.shape))
#     519         else:
#     520             p.set_value(v)
#
# ValueError: mismatch: parameter has shape (1, 1, 1, 1) but value to set has shape (1, 1, 3, 3)

# %%
learn(network,
      X_y,
      watches=['obj',
               'recall',
               'precision',
               'accuracy',
               'loss',
               'sub_loss',
               'total_complexity',
               'complexity_parts'],
      num_epochs=100,
      batch_size=50)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Epoch 1 of 100 took 36.828s
# Epoch 2 of 100 took 36.987s
# Epoch 3 of 100 took 41.613s
# Epoch 4 of 100 took 42.025s
# Epoch 5 of 100 took 42.088s
# Epoch 6 of 100 took 42.045s
# Epoch 7 of 100 took 41.934s
# Epoch 8 of 100 took 42.032s
# Epoch 9 of 100 took 42.125s
# Epoch 10 of 100 took 41.774s
# Epoch 11 of 100 took 41.575s
# Epoch 12 of 100 took 41.595s
# Epoch 13 of 100 took 41.627s
# Epoch 14 of 100 took 41.635s
# Epoch 15 of 100 took 41.587s
# Epoch 16 of 100 took 41.633s
# Epoch 17 of 100 took 41.732s
# Epoch 18 of 100 took 41.818s
# Epoch 19 of 100 took 41.807s
# Epoch 20 of 100 took 41.807s
# Epoch 21 of 100 took 41.752s
# Epoch 22 of 100 took 41.760s
# Epoch 23 of 100 took 41.782s
# Epoch 24 of 100 took 41.852s
# Epoch 25 of 100 took 42.162s
# Epoch 26 of 100 took 71.448s
# Epoch 27 of 100 took 37.713s
# Epoch 28 of 100 took 37.713s
# Epoch 29 of 100 took 37.956s
# Epoch 30 of 100 took 37.702s
# Epoch 31 of 100 took 37.602s
# Epoch 32 of 100 took 37.716s
# Epoch 33 of 100 took 37.715s
# Epoch 34 of 100 took 41.882s
# Epoch 35 of 100 took 41.967s
# Epoch 36 of 100 took 41.903s
# Epoch 37 of 100 took 42.610s
# Epoch 38 of 100 took 41.664s
# Epoch 39 of 100 took 41.877s
# Epoch 40 of 100 took 41.919s
# Epoch 41 of 100 took 41.887s
# Epoch 42 of 100 took 41.988s
# Epoch 43 of 100 took 42.806s
# Epoch 44 of 100 took 41.903s
# Epoch 45 of 100 took 41.829s
# Epoch 46 of 100 took 42.127s
# Epoch 47 of 100 took 43.331s
# Epoch 48 of 100 took 41.818s
# Epoch 49 of 100 took 71.808s
# Epoch 50 of 100 took 37.714s
# Epoch 51 of 100 took 38.738s
# Epoch 52 of 100 took 38.845s
# Epoch 53 of 100 took 38.772s
# Epoch 54 of 100 took 38.136s
# Epoch 55 of 100 took 38.862s
# Epoch 56 of 100 took 39.572s
# Epoch 57 of 100 took 43.370s
# Epoch 58 of 100 took 43.301s
# Epoch 59 of 100 took 41.896s
# Epoch 60 of 100 took 42.469s
# Epoch 61 of 100 took 41.994s
# Epoch 62 of 100 took 41.924s
# Epoch 63 of 100 took 41.911s
# Epoch 64 of 100 took 41.885s
# Epoch 65 of 100 took 41.896s
# Epoch 66 of 100 took 41.874s
# Epoch 67 of 100 took 41.915s
# Epoch 68 of 100 took 41.891s
# Epoch 69 of 100 took 41.943s
# Epoch 70 of 100 took 41.816s
# Epoch 71 of 100 took 41.854s
# Epoch 72 of 100 took 42.688s
# Epoch 73 of 100 took 43.217s
# Epoch 74 of 100 took 41.828s
# Epoch 75 of 100 took 70.903s
# Epoch 76 of 100 took 37.585s
# Epoch 77 of 100 took 37.612s
# Epoch 78 of 100 took 37.679s
# Epoch 79 of 100 took 37.702s
# Epoch 80 of 100 took 37.651s
# Epoch 81 of 100 took 37.996s
# Epoch 82 of 100 took 38.320s
# Epoch 83 of 100 took 42.546s
# Epoch 84 of 100 took 42.664s
# Epoch 85 of 100 took 43.118s
# Epoch 86 of 100 took 42.860s
# Epoch 87 of 100 took 43.145s
# Epoch 88 of 100 took 43.190s
# Epoch 89 of 100 took 42.881s
# Epoch 90 of 100 took 42.423s
# Epoch 91 of 100 took 41.902s
# Epoch 92 of 100 took 41.816s
# Epoch 93 of 100 took 41.744s
# Epoch 94 of 100 took 41.802s
# Epoch 95 of 100 took 41.636s
# Epoch 96 of 100 took 41.758s
# Epoch 97 of 100 took 74.902s
# Epoch 98 of 100 took 37.639s
# Epoch 99 of 100 took 37.663s
# Epoch 100 of 100 took 37.687s

# %%
network.save('../weights', '4cascades')

# %%
params = lasagne.layers.get_all_param_values(network.output_layer)

# %%
params[12].shape
# Out:
# (6, 3, 3, 3)

# %% [markdown]
# ## Adjust Coefficients and add more data

# %%
X_y = train_test_split(dataset, track_targets)

# %%
network = CascadeBase(img_shape=(512, 512),
                      learning_rate=1e-3,
                      c=1e-1,
                      c_complexity=3e-1,
                      c_sub_objs=[5e-2, 5e-2, 1, 1],
                      c_sub_obj_cs=[1e-2, 5e-2, 1e-1, 1e-1],
                      mul=True,
                      pool_sizes=[2, 2, 2, 2],
                      num_filters=[1, 1, 3, 6],
                      filter_sizes=[1, 3, 3, 3],
                      l2_c=1e-4)

# %%
network.load('../weights', '4cascades')

# %%
learn(network,
      X_y,
      watches=['obj',
               'recall',
               'precision',
               'accuracy',
               'loss',
               'sub_loss',
               'total_complexity',
               'complexity_parts'],
      num_epochs=200,
      batch_size=50)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Epoch 1 of 200 took 37.309s
# Epoch 2 of 200 took 38.127s
# Epoch 3 of 200 took 38.533s
# Epoch 4 of 200 took 38.566s
# Epoch 5 of 200 took 38.616s
# Epoch 6 of 200 took 38.440s
# Epoch 7 of 200 took 38.496s
# Epoch 8 of 200 took 40.209s
# Epoch 9 of 200 took 42.919s

# %%
network.load('../weights', '4cascades')

# %%
network.save('../weights', '3cascades_difficult_clear')

# %% [markdown]
# # Check results

# %%
# %matplotlib inline
i = np.random.choice(X_y[-1].shape[0])

plt.imshow(X_y[1][i][0])
plt.colorbar()
plt.show()

plt.imshow(X_y[-1][i][0], interpolation='none')
plt.colorbar()
plt.show()

prediction = network.predict(X_y[1][i:i + 1].astype(np.float32))

plt.imshow(prediction[0, 0], interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

plt.imshow(prediction[0, 0] < 0.5, interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

plt.imshow(prediction[0, 0] >= 0.5, interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

target = get_target(X_y[-1][i].reshape(1,1,512,512))[0, 0]
plt.imshow(target, interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

plt.imshow(target - (prediction[0, 0] > 0.071730167), interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

# %%
for branch in network.branches:
# Out:
# [<lasagne.layers.conv.Conv2DLayer at 0x7f39d8c3cd90>,
#  <lasagne.layers.conv.Conv2DLayer at 0x7f39ca7017d0>,
#  <lasagne.layers.conv.Conv2DLayer at 0x7f39ca701f10>,
#  <lasagne.layers.conv.Conv2DLayer at 0x7f39d8cfbfd0>]

# %%
print 1
# Out:
# 1

# %% [markdown]
# # Precision Vs Recall

# %%
import theano
get_target = theano.function([network.targets], lasagne.layers.get_output(network.target_pool_layers[-1]))

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

x_val = X_y[1][:100]
y_val = X_y[-1][:100]

prediction = network.predict(x_val)
target = get_target(y_val)

precision, recall, thr = precision_recall_curve(target.ravel(), prediction.ravel())
average_precision = average_precision_score(target.ravel(), prediction.ravel())

# Plot Precision-Recall curve
plt.clf()
plt.plot(recall, precision, label='Precision-Recall curve')
plt.plot(np.arange(thr.shape[0]) / (thr.shape[0] + 1e-6), thr, label='Threshold')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall example: AUC={0:0.2f}'.format(average_precision))
plt.legend(loc='best')
plt.show()

# %%
precision[30000]
# Out:
# 0.26052561008313219

# %%
thr[30000]
# Out:
# 0.071730167

# %%
recall[30000]
# Out:
# 0.99082100968893416

# %%
imgs[2].shape
# Out:
# (128, 128)

# %%
for img in imgs:
    plt.imshow(img)
    plt.colorbar()
    plt.show()

# %%
plt.imshow(X_y[1][150].reshape([512, 512]))
plt.colorbar()

# %%
plt.imshow(X_y[-1][150].reshape([512, 512]))

# %%
imgs = []

for f in intermediate_funs:
    imgs.append(f(X_y[1][150:151]))

# %%
plt.imshow(g.reshape(g.shape[2:]))

# %%
with open('../imgs.pkl', 'wb') as f:
    pickle.dump(imgs, f)

# %%
with open('../img_gt.pkl', 'wb') as f:
    pickle.dump([X_y[1][150], X_y[-1][150]], f)
